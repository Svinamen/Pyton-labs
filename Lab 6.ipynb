# %% [markdown]
# # Лабораторная работа № 6
# Вариант 1

# %%
import pandas as pd
import numpy as np
import re
df = pd.read_csv("D:\DATAFRAME\F.csv")
df
df.index.name = 'index'
df
# Out:
#                               Title              Author       Genre  \
# index
# 0          Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                        Data Smart       Foreman, John        tech
# 2          God Created the Integers    Hawking, Stephen        tech
# 3                 Superfreakonomics     Dubner, Stephen     science
# 4                       Orientalism        Said, Edward  nonfiction
# ...                             ...                 ...         ...
# 206        Structure and Randomness        Tao, Terence     science
# 207    Image Processing with MATLAB       Eddins, Steve        tech
# 208                     Animal Farm      Orwell, George     fiction
# 209                      Idiot, The  Dostoevsky, Fyodor     fiction
# 210              Christmas Carol, A    Dickens, Charles     fiction
#
#                 SubGenre  Height      Publisher
# index
# 0      signal_processing     228          Wiley
# ...

# %%
#2
df["WordsInTitle"] = pd.Series(df['Title'].str.split(" ").str.len(), index = df.index)
df
# Out:
#                               Title              Author       Genre  \
# index
# 0          Fundamentals of Wavelets    Goswami, Jaideva        tech
# 1                        Data Smart       Foreman, John        tech
# 2          God Created the Integers    Hawking, Stephen        tech
# 3                 Superfreakonomics     Dubner, Stephen     science
# 4                       Orientalism        Said, Edward  nonfiction
# ...                             ...                 ...         ...
# 206        Structure and Randomness        Tao, Terence     science
# 207    Image Processing with MATLAB       Eddins, Steve        tech
# 208                     Animal Farm      Orwell, George     fiction
# 209                      Idiot, The  Dostoevsky, Fyodor     fiction
# 210              Christmas Carol, A    Dickens, Charles     fiction
#
#                 SubGenre  Height      Publisher  WordsInTitle
# index
# 0      signal_processing     228          Wiley             3
# ...

# %%
#3
text= df.dropna()
text[text['Author'].str.contains('(?i)\w*[^aeoiuy]{3}\w*,')]
# Out:
#                                                    Title               Author  \
# index
# 13       Structure & Interpretation of Computer Programs      Sussman, Gerald
# 18                                  New Machiavelli, The         Wells, H. G.
# 24                              Python for Data Analysis        McKinney, Wes
# 35                                   Farewell to Arms, A    Hemingway, Ernest
# 37                                     False Impressions      Archer, Jeffery
# 38                                     Last Lecture, The        Pausch, Randy
# 40                                         Jurassic Park    Crichton, Michael
# 46                                           Asami Asami       Deshpande, P L
# 58                                       Learning OpenCV        Bradsky, Gary
# 63                              Amulet of Samarkand, The     Stroud, Jonathan
# 64                                  Crime and Punishment   Dostoevsky, Fyodor
# ...

# %%
#4
df[df['Author'].str.split(" ").str[1].str.len().max() == df['Author'].str.split(" ").str[1].str.len()]
# Out:
#                                Title             Author       Genre SubGenre  \
# index
# 26     Beautiful and the Damned, The    Deb, Siddhartha  nonfiction  history
# 121          Discovery of India, The  Nehru, Jawaharlal  nonfiction  history
#
#        Height Publisher  WordsInTitle
# index
# 26        198   Penguin             5
# 121       230       NaN             4

# %%
#5
df[(df['WordsInTitle'] > 1) &(df['Title'].str.split(" ").str[1].str.startswith("C"))]
# Out:
#                                           Title              Author  \
# index
# 2                      God Created the Integers    Hawking, Stephen
# 44                      Hidden Connections, The      Capra, Fritjof
# 55         Soft Computing & Intelligent Systems        Gupta, Madan
# 75        Social Choice & Welfare, Vol 39 No. 1             Various
# 105    Maugham's Collected Short Stories, Vol 3  Maugham, William S
# 134                      Pattern Classification          Duda, Hart
# 138                                Final Crisis                 NaN
# 167                         Jim Corbett Omnibus        Corbett, Jim
# 169                             Batatyachi Chal       Deshpande P L
# 175                            Think Complexity       Downey, Allen
# 210                          Christmas Carol, A    Dickens, Charles
#
#             Genre      SubGenre  Height      Publisher  WordsInTitle
# index
# ...

# %%
#6
df[df['Title'].str.split(" ").str[:].str.len() == 1]
# Out:
#                    Title              Author       Genre       SubGenre  \
# index
# 3      Superfreakonomics     Dubner, Stephen     science      economics
# 4            Orientalism        Said, Edward  nonfiction        history
# 43          Freakonomics     Dubner, Stephen     science      economics
# 72                Scoop!       Nayar, Kuldip  nonfiction        history
# 79        Maqta-e-Ghalib        Garg, Sanjay  nonfiction         poetry
# 81                Manasa           Kale, V P  nonfiction           misc
# 117                  One       Bach, Richard  nonfiction  autobiography
# 122               Apulki      Deshpande, P L  nonfiction           misc
# 140           Flashpoint                 NaN     fiction          comic
# 166               Mossad  Baz-Zohar, Michael  nonfiction        history
# 170           Hafasavnuk       Deshpande P L     fiction          novel
# 171            Urlasurla       Deshpande P L     fiction          novel
#
# ...

# %%
#7
temp = df[df['Title'].str.contains('[0-9_]+')][['Title']]
temp
# Out:
#                                           Title
# index
# 52                                     Catch 22
# 75        Social Choice & Welfare, Vol 39 No. 1
# 105    Maugham's Collected Short Stories, Vol 3
# 143                 Numbers Behind Numb3rs, The
# 144                      Superman Earth One - 1
# 145                      Superman Earth One - 2
# 153          Journal of Economics, vol 106 No 3
# 168                 20000 Leagues Under the Sea

# %%
#8
text = temp
text = pd.DataFrame(temp['Title'].str.findall('[0-9]'))
text['Title'] = text['Title']
text['Title'] = [''.join(text['Title'].values[w]) for w in range(len(text))]
text
# Out:
#        Title
# index
# 52        22
# 75       391
# 105        3
# 143        3
# 144        1
# 145        2
# 153     1063
# 168    20000
