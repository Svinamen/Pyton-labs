# %% [markdown]
# # Лаболаторна робота № 1

# %% [markdown]
# ### Вариант 6: ` Йорданія - Йорда́нське Хашимі́тське Королі́вство`

# %% [markdown]
# <html>
# <body>
# <p style="background-color:rgb(255, 165, 0);">Отримала незалежність 25 травня 1946 року</p>
# </body>
# </html>
#
# ***

# %% [markdown]
# >Адміністративний поділ Йорданії
#
# ***
# >>Повне населення королівства на стан 2011 року складає 6500000 осіб
#
# Провінції     | Площа км2 | Населення (2004 рік)
# :------------ |:---------:| --------------------:
# Аджлун        |412        |118496
# Акаба         |6583       |101736
# Амман         |8231       |1 939 405
# Джераш        |402        |153 650
# Ірбід         |1621       |925 736
# Маан          |33163      |92762
# Мадаба        |2008       |129792
# Ез-Зарка      |4080       |774569
# Ель-Балка     |1076       |344985
# Ель-Карак     |3217       |204135
# Ель-Мафрак    |26435      |240515
# Ет-Тафіла     |2114       |75290

# %% [markdown]
# ### найдвніші часи
#
# + У період неоліту (8500-4500 рр. До н. Е.) Починає розвиватися сільське господарство. У поселенні Айн-Газаль на півночі Аммана (Докерамічний неоліт B) виявлені гіпсові статуї, що представляють собою одні з найбільш ранніх великоформатних зображень людини.
#
# + У період халколита (4500-3200 рр. До н. Е.) В Фейнане почали плавити мідь. Виявлено фрески цього періоду в селі Телелат Аль-Гхасуль.
#
# + У період бронзового століття (3200-1200 рр. До н. Е.) Бурхливо розвиваються поселення, разом з ними архітектура, знаряддя праці, мистецтво, торгівля. Під час пізнього бронзового століття територія Йорданії потрапляє під вплив Єгипту.
#
# + Близько 1300 р. До н.е. е. територія на сході від річки Йордан, відповідна сучасної Йорданії, країни Моав і Аман (Аммон) були захоплені єврейськими племенами Реувена, Гада і половиною коліна Менаше, де вони побудували укріплені міста і розвинули скотарство на пишних пасовищах. Аж до 1 століття н. е. ці місця населяли євреї, і Зайордання було частиною єврейської держави. У наш час археологами знайдено велику кількість історичних пам'яток, які підтверджують єврейське заселення цих земель в зазначений період.
#
# + Під час залізного віку (1200-332 рр. До н. Е.) Територія Йорданії поділяється між євреями, амонітами, моавітів і едомітамі. До цього періоду відноситься основна частина подій Старого Завіту. Високорозвинене сільське господарство існувало на півночі Йорданії. До цього періоду відноситься велика кількість поселень в Аммані, Дейбане, Мадабе, горе Небо, Бусєре і Караке.

# %% [markdown]
# # Статуя Айн-Газаля
# ![статуяя айн-газаля](https://upload.wikimedia.org/wikipedia/commons/thumb/a/a9/Ain_Ghazal_Statue_Jordan_Archaeological_Museum_Amman_Jordan0821.jpg/447px-Ain_Ghazal_Statue_Jordan_Archaeological_Museum_Amman_Jordan0821.jpg "fdvdsf")

# %% [markdown]
# <!DOCTYPE html>
# <html lang="ru">
# <head>
#     <meta charset="UTF-8">
#
# </head>
# <body>
# <h1>Клімат</h1>
# <p style="background: #27b9e6;border:15px #e30715 ridge; width: 300px; padding: 5px 10px 10px 10px; margin:50px 0 50px 275px;" >_Клімат_ в Йорданії субтропічний, сухий із спекотним літом. Чим далі вглиб країни від Середземного моря, тим більший контраст температур спостерігається і тим менше опадів там випадає. Середня висота країни становить 812 м. У нагір'ях над долиною річки Йордан, горах Мертвого моря і Ваді-ель-Араба переважає середземноморський клімат, у той час як східні і північно-східні райони країни є посушливою пустелею. Незважаючи на те, що в пустельній частині Йорданії висока температура повітря, клімат пом'якшується низькою вологістю, денним бризом та прохолодою вночі.</p>
# </body>
# </html>

# %% [markdown]
# ***Завдання 5: Вести 2 числа a і b. Знайти всі прості числа на відрізку [a,b]***

# %%
# %%html
# <html lang="ru">
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
# <svg display="none">
#     <symbol viewBox="0 0 640 480" id="Jordan">
#         <g>
#             <path d="M-117.8 0h1024v170.7h-1024z"/>
#             <path fill="#fff" d="M-117.8 170.7h1024v170.6h-1024z"/>
#             <path fill="#090" d="M-117.8 341.3h1024V512h-1024z"/>
#             <path fill="red" d="M-117.8 512l512-256-512-256v512z"/>
#             <path fill="#fff" d="M24.5 289l5.7-24.9H4.7l23-11-15.9-19.9 23 11 5.6-24.8 5.7 24.9L69 233.2l-16 19.9 23 11H50.6l5.7 24.9-15.9-20z"/>
#         </g>
#     </symbol>
# </svg>
#
# <svg>
#     <use xlink:href="#Jordan"></use>
# </svg>
# </body>
# </html>
# Out:
# <html lang="ru">
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
# <svg display="none">
#     <symbol viewBox="0 0 640 480" id="Jordan">
#         <g>
#             <path d="M-117.8 0h1024v170.7h-1024z"/>
#             <path fill="#fff" d="M-117.8 170.7h1024v170.6h-1024z"/>
#             <path fill="#090" d="M-117.8 341.3h1024V512h-1024z"/>
#             <path fill="red" d="M-117.8 512l512-256-512-256v512z"/>
#             <path fill="#fff" d="M24.5 289l5.7-24.9H4.7l23-11-15.9-19.9 23 11 5.6-24.8 5.7 24.9L69 233.2l-16 19.9 23 11H50.6l5.7 24.9-15.9-20z"/>
#         </g>
#     </symbol>
# </svg>
#
# <svg>
#     <use xlink:href="#Jordan"></use>
# </svg>
# </body>
# </html>

# %%
while True:
    a = input("Введите целое число больше 0: ")
    if not a.isnumeric():
        print("ERROR")
    elif int(a) <= 0:
        print("ERROR")
    else:
        a = int(a)
        break   
while True:
    b = input("Введите целое число больше " + str(a) + " :")
    if not b.isnumeric():
        print("ERROR")
    elif int(b) <= 0 and int(b) > a:
        print("ERROR")
    else:
        b = int(b)
        break
x = []
for i in range(a,b):
    if (i % 2 != 0 or i == 2) and (i % 3 != 0 or i == 3) and (i % 5 != 0 or i == 5) and (i % 7 != 0 or i == 7) and i != 1:
        x.append(i)
print(x)
